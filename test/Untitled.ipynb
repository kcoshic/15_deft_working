# %%
matplotlib inline

# %%
run test_deft_2d.py
# Out:
# data_type=face, alpha=4, N=100
# t == 0.00
# t == -0.60
# t == -1.26
# t == -2.00
# t == -2.81
# t == -3.62
# t == -4.39
# t == -5.17
# t == -5.94
# t == -6.66
# t == -7.30
# t == -7.86
# t == -8.38
# t == -8.87
# t == -9.37
# t == -9.93
# t == -10.59
# t == -11.55
# t == 0.60
# t == 1.14
# t == 1.63
# t == 2.09
# MAP curve computation took 3.47 sec
# compute_maxent_prob took 4.803318 sec

# %%
5+3
# Out:
# 8
