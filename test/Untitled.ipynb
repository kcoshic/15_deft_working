# %%
matplotlib inline

# %%
run test_deft_2d.py
# Out:
# data_type=digit, alpha=7, N=1000
# t == 0.00
# t == -0.93
# t == -1.80
# t == -2.70
# t == -3.64
# t == -4.61
# t == -5.51
# t == -6.35
# t == 0.93
# t == 1.99
# t == 3.07
# t == 4.21
# t == 5.35
# t == 6.49
# MAP curve computation took 3.25 sec
# compute_maxent_prob took 4.414302 sec
